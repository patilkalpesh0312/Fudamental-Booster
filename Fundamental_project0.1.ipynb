# %% [markdown]
# # .....FUNDAMENTAL BOOSTER PROJECT.....
#
# *data types ,variable & operators:*

# %%
print("welcome to the interactive personal data collector \n")
# Out:
# welcome to the interactive personal data collector

# %%
age = int(input("enter your age"))
height = float(input("enter your height in meters"))
print(f"age: your are age:",age)
print(type(age))
print(type(height))
print(id ("age"))
print(id("height"))
# Out:
# enter your age 18
# enter your height in meters 584.45
# age: your are age: 18
# <class 'int'>
# <class 'float'>
# 1944764045024
# 1944708168608

# %% [markdown]
# # .....types of constrution.....

# %%
current_year = 2026
birth_year = 2007
print(f"\nyour birth year is approximately: {birth_year}(based on your age of {age}")
# Out:
# your birth year is approximately: 2007(based on your age of 18

# %% [markdown]
# # Thank you for using the personal Data collector.Goodbye!
