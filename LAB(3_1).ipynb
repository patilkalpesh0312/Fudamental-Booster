# %% [markdown]
# # ***Q-1***

# %%
number = int(input("pls enter your sutable number"))
if number %2 == 0:
    print("it;s even")
else:
    print("it;s odd")
# Out:
# pls enter your sutable number 12
# it;s even

# %% [markdown]
# # Q-2

# %% [markdown]
# # New Section

# %%
age = int(input("👉pls enter your age:👈"))

if age >= 0:
    if age <= 12:
        print("childe❤️❤️")
    else:
        if age <= 19:
            print("Teenager😁")
        else:
            if age <= 59:
                print("Adult🤦‍♂️")
            else:
                print("Senior😱")
# Out:
# 👉pls enter your age:👈 17
# Teenager😁

# %% [markdown]
# # Q-3

# %%
A = int(input("enter the first number "))
B = int(input("enter the seconde number "))
C = int(input("enter the third number "))

if A >= B and A >= C:
    print("largest number is:",A)
elif B >= A and B>= C:
    print("largest number is:",B)
else:
    print("largest number is:",C)
# Out:
# enter the first number  2
# enter the seconde number  2
# enter the third number  2
# largest number is: 2

# %% [markdown]
# # Q-4

# %%
num = int(input("enter any natural number"))

if number > 0:
    print("this is positive number")
elif  num == 0:
    print("this is zero")
else:
    print("this is a negative number")
# Out:
# enter any natural number 0
# this is zero

# %% [markdown]
# # ********* END OF CODE *********
