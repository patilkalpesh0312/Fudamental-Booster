# %%
print("\n--- student details---" )
# Out:
# --- student details---

# %%
food =  input("enter your food")
movie = input("enter your movie")
colour = input("enter your colour")
print("\n my favorite food:",food)
print("my favorite movie:",movie)
print("my favorite colour:",colour)
# Out:
# enter your food brod
# enter your movie cars3
# enter your colour white
#  my favorite food: brod
# my favorite movie: cars3
# my favorite colour: white

# %%
name = "kalpesh"
age = "17"
city = "surat"
print("hello , my name is",name)
print("i am" , age,"years old")
print("i live in",city)
# Out:
# hello , my name is kalpesh
# i am 17 years old
# i live in surat

# %%
name = input ("enter your name :")
course = input("inter your course")
school = input("inter your school")

print ("\n--- STUDENT DEATAILS ---")
print ("name :",name)
print ("course :",course)
print ("school :",school)
# Out:
# enter your name : kalpesh
# inter your course dsa
# inter your school mmps

# %%
tem = input("today temp ")
print("\n today temp is ___:","c")
# Out:
# today temp  30
#  today temp is ___: c

# %%
first_name = input("enter your first name:")
last_name = input("enter your last name:")
username = first_name+"_"+last_name
print("your username is ;",username)
# Out:
# enter your first name: kalpesh
# enter your last name: patil
# your username is ; kalpesh_patil

# %%
name =input("enter your name")
age = input("enter your age")
skills = input("enter your skills")
city = input("enter your city")

print("\n----PROFILE----")
print("name:",name)
print("age:",age)
print("skills:",skills)
print("city:",skills)
print("--------------")
# Out:
# enter your name kalpesh
# enter your age 17
# enter your skills DSA
# enter your city city
# ----PROFILE----
# name: kalpesh
# age: 17
# skills: DSA
# city: DSA
# --------------
